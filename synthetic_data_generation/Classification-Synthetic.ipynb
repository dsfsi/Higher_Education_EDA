# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import cross_val_score

from sklearn.neighbors import KNeighborsClassifier
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import learning_curve
from sklearn import datasets
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import cross_val_score

from sklearn.neighbors import KNeighborsClassifier
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import learning_curve
from sklearn import datasets
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from mlxtend.plotting import plot_learning_curves
import matplotlib.pyplot as plt
from mlxtend.data import mnist_data
from mlxtend.preprocessing import shuffle_arrays_unison
from sklearn.neighbors import KNeighborsClassifier
import numpy as np

# %%
educationdata1 = pd.read_csv("filepath")
educationdata2 = pd.read_csv("filepath")
educationdata3 = pd.read_csv("filepath")
educationdata4 = pd.read_csv("filepath")
educationdata5 = pd.read_csv("filepath")

# %%
x11 = educationdata1.drop("final_result", axis = 1)
y11 = educationdata1.final_result
x21 = educationdata1.drop("final_result", axis = 1)
y21 = educationdata1.final_result
x_train1 = x11
y_train1 = y11
x_test1 = x11
y_test1 = y11

# %%
x12 = educationdata2.drop("final_result", axis = 1)
y12 = educationdata2.final_result
x22 = educationdata2.drop("final_result", axis = 1)
y22 = educationdata2.final_result
x_train2 = x12
y_train2 = y12
x_test2 = x12
y_test2 = y12

# %%
x13 = educationdata3.drop("final_result", axis = 1)
y13 = educationdata3.final_result
x23 = educationdata3.drop("final_result", axis = 1)
y23 = educationdata3.final_result
x_train3 = x13
y_train3 = y13
x_test3 = x13
y_test3 = y13

# %%
x14 = educationdata4.drop("final_result", axis = 1)
y14 = educationdata4.final_result
x24 = educationdata4.drop("final_result", axis = 1)
y24 = educationdata4.final_result
x_train4 = x14
y_train4 = y14
x_test4 = x14
y_test4 = y14

# %%
x15 = educationdata5.drop("final_result", axis = 1)
y15 = educationdata5.final_result
x25 = educationdata5.drop("final_result", axis = 1)
y25 = educationdata5.final_result
x_train5 = x15
y_train5 = y15
x_test5 = x15
y_test5 = y15

# %%
educationdata1_corr = educationdata1.corr()
educationdata2_corr = educationdata2.corr()
educationdata3_corr = educationdata3.corr()
educationdata4_corr = educationdata4.corr()
educationdata5_corr = educationdata5.corr()

# %%
f,ax = plt. subplots(figsize = (10,10))
sns.heatmap(educationdata1_corr, annot = False, )
f,ax = plt. subplots(figsize = (10,10))
sns.heatmap(educationdata2_corr, annot = False, )
f,ax = plt. subplots(figsize = (10,10))
sns.heatmap(educationdata3_corr, annot = False, )
f,ax = plt. subplots(figsize = (10,10))
sns.heatmap(educationdata4_corr, annot = False, )
f,ax = plt. subplots(figsize = (10,10))
sns.heatmap(educationdata5_corr, annot = False, )

# %%
mask = np.zeros_like(educationdata1_corr)
mask[np.triu_indices_from(mask)] = True
with sns.axes_style("white"):
    f, ax = plt.subplots(figsize=(7, 5))
    ax = sns.heatmap(educationdata1_corr, mask=mask, vmax=1, square=True)

# %%
mask = np.zeros_like(educationdata2_corr)
mask[np.triu_indices_from(mask)] = True
with sns.axes_style("white"):
    f, ax = plt.subplots(figsize=(7, 5))
    ax = sns.heatmap(educationdata2_corr, mask=mask, vmax=1, square=True)

# %%
mask = np.zeros_like(educationdata3_corr)
mask[np.triu_indices_from(mask)] = True
with sns.axes_style("white"):
    f, ax = plt.subplots(figsize=(7, 5))
    ax = sns.heatmap(educationdata3_corr, mask=mask, vmax=1, square=True)

# %%
mask = np.zeros_like(educationdata4_corr)
mask[np.triu_indices_from(mask)] = True
with sns.axes_style("white"):
    f, ax = plt.subplots(figsize=(7, 5))
    ax = sns.heatmap(educationdata4_corr, mask=mask, vmax=1, square=True)

# %%
mask = np.zeros_like(educationdata5_corr)
mask[np.triu_indices_from(mask)] = True
with sns.axes_style("white"):
    f, ax = plt.subplots(figsize=(7, 5))
    ax = sns.heatmap(educationdata5_corr, mask=mask, vmax=1, square=True)

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier()
rf.fit(x_train1, y_train1)
rf_pred = rf.predict(x_test1)

# %%
rf3 = RandomForestClassifier()
rf.fit(x_train3, y_train3)
rf_pred = rf.predict(x_test3)
pipeline = make_pipeline(StandardScaler(), rf3)

train_sizes, train_scores, test_scores = learning_curve(estimator = pipeline, X=x_train3, y=y_train3,
                                                       cv=10, train_sizes=np.linspace(0.1,1,10),
                                                     n_jobs=1)
train_mean = np.mean(train_scores, axis=1)
train_std = np.std(train_scores, axis=1)
test_mean = np.mean(test_scores, axis=1)
test_std = np.std(test_scores, axis=1)

plt.plot(train_sizes, train_mean, color='blue', marker='o', markersize=5, label='Training Score')
plt.fill_between(train_sizes, train_mean + train_std, train_mean - train_std, alpha=0.15, color='blue')
plt.plot(train_sizes, test_mean, color='green', marker='+', markersize=5, linestyle='--', label='Cross Validation Score')
plt.fill_between(train_sizes, test_mean + test_std, test_mean - test_std, alpha=0.15, color='green')
plt.title('All Columbian Engineering data')
plt.xlabel('Training Data Size')
plt.ylabel('Model Score')
plt.grid()
plt.ylim(0.0, 1.10)
plt.legend(loc='lower right')
plt.show()

# %%
rf4 = RandomForestClassifier()
rf.fit(x_train4, y_train4)
rf_pred = rf.predict(x_test4)
pipeline = make_pipeline(StandardScaler(), rf4)

train_sizes, train_scores, test_scores = learning_curve(estimator = pipeline, X=x_train4, y=y_train4,
                                                       cv=10, train_sizes=np.linspace(0.1,1,10),
                                                     n_jobs=1)
train_mean = np.mean(train_scores, axis=1)
train_std = np.std(train_scores, axis=1)
test_mean = np.mean(test_scores, axis=1)
test_std = np.std(test_scores, axis=1)

plt.plot(train_sizes, train_mean, color='blue', marker='o', markersize=5, label='Training Score')
plt.fill_between(train_sizes, train_mean + train_std, train_mean - train_std, alpha=0.15, color='blue')
plt.plot(train_sizes, test_mean, color='green', marker='+', markersize=5, linestyle='--', label='Cross Validation Score')
plt.fill_between(train_sizes, test_mean + test_std, test_mean - test_std, alpha=0.15, color='green')
plt.title('All SPU data')
plt.xlabel('Training Data Size')
plt.ylabel('Model Score')
plt.grid()
plt.ylim(0.0, 1.10)
plt.legend(loc='lower right')
plt.show()

# %%
rf5 = RandomForestClassifier()
rf.fit(x_train5, y_train5)
rf_pred = rf.predict(x_test5)
pipeline = make_pipeline(StandardScaler(), rf5)

train_sizes, train_scores, test_scores = learning_curve(estimator = pipeline, X=x_train5, y=y_train5,
                                                       cv=10, train_sizes=np.linspace(0.1,1,10),
                                                     n_jobs=1)
train_mean = np.mean(train_scores, axis=1)
train_std = np.std(train_scores, axis=1)
test_mean = np.mean(test_scores, axis=1)
test_std = np.std(test_scores, axis=1)

plt.plot(train_sizes, train_mean, color='blue', marker='o', markersize=5, label='Training Score')
plt.fill_between(train_sizes, train_mean + train_std, train_mean - train_std, alpha=0.15, color='blue')
plt.plot(train_sizes, test_mean, color='green', marker='+', markersize=5, linestyle='--', label='Cross Validation Score')
plt.fill_between(train_sizes, test_mean + test_std, test_mean - test_std, alpha=0.15, color='green')
plt.title('All OU STEM data')
plt.xlabel('Training Data Size')
plt.ylabel('Model Score')
plt.grid()
plt.ylim(0.0, 1.10)
plt.legend(loc='lower right')
plt.show()

# %%
educationdata6 = pd.read_csv("filepath")
educationdata7 = pd.read_csv("filepath")
educationdata8 = pd.read_csv("filepath")
educationdata9 = pd.read_csv("filepath")
educationdata10 = pd.read_csv("filepath")

# %%
x16 = educationdata6.drop("final_result", axis = 1)
y16 = educationdata6.final_result
x_train6 = x16
y_train6 = y16
x_test6 = x16
y_test6 = y16

# %%
x18 = educationdata8.drop("final_result", axis = 1)
y18 = educationdata8.final_result
x_train8 = x18
y_train8 = y18
x_test8 = x18
y_test8 = y18
rf8 = RandomForestClassifier()
rf.fit(x_train8, y_train8)
rf_pred = rf.predict(x_test8)
pipeline = make_pipeline(StandardScaler(), rf8)

train_sizes, train_scores, test_scores = learning_curve(estimator = pipeline, X=x_train8, y=y_train8,
                                                       cv=10, train_sizes=np.linspace(0.1,1,10),
                                                     n_jobs=1)
train_mean = np.mean(train_scores, axis=1)
train_std = np.std(train_scores, axis=1)
test_mean = np.mean(test_scores, axis=1)
test_std = np.std(test_scores, axis=1)

plt.plot(train_sizes, train_mean, color='blue', marker='o', markersize=5, label='Training Score')
plt.fill_between(train_sizes, train_mean + train_std, train_mean - train_std, alpha=0.15, color='blue')
plt.plot(train_sizes, test_mean, color='green', marker='+', markersize=5, linestyle='--', label='Cross Validation Score')
plt.fill_between(train_sizes, test_mean + test_std, test_mean - test_std, alpha=0.15, color='green')
plt.title('Columbian Engineering data without demography')
plt.xlabel('Training Data Size')
plt.ylabel('Model Score')
plt.grid()
plt.ylim(0.0, 1.10)
plt.legend(loc='lower right')
plt.show()

# %%
x19 = educationdata9.drop("final_result", axis = 1)
y19 = educationdata9.final_result
x_train9 = x19
y_train9 = y19
x_test9 = x19
y_test9 = y19
rf9 = RandomForestClassifier()
rf.fit(x_train9, y_train9)
rf_pred = rf.predict(x_test9)
pipeline = make_pipeline(StandardScaler(), rf9)

train_sizes, train_scores, test_scores = learning_curve(estimator = pipeline, X=x_train9, y=y_train9,
                                                       cv=10, train_sizes=np.linspace(0.1,1,10),
                                                     n_jobs=1)
train_mean = np.mean(train_scores, axis=1)
train_std = np.std(train_scores, axis=1)
test_mean = np.mean(test_scores, axis=1)
test_std = np.std(test_scores, axis=1)

plt.plot(train_sizes, train_mean, color='blue', marker='o', markersize=5, label='Training Score')
plt.fill_between(train_sizes, train_mean + train_std, train_mean - train_std, alpha=0.15, color='blue')
plt.plot(train_sizes, test_mean, color='green', marker='+', markersize=5, linestyle='--', label='Cross Validation Score')
plt.fill_between(train_sizes, test_mean + test_std, test_mean - test_std, alpha=0.15, color='green')
plt.title('SPU Student data without demography')
plt.xlabel('Training Data Size')
plt.ylabel('Model Score')
plt.grid()
plt.ylim(0.0, 1.10)
plt.legend(loc='lower right')
plt.show()

# %%
x110 = educationdata10.drop("final_result", axis = 1)
y110 = educationdata10.final_result
x_train10 = x110
y_train10 = y110
x_test10 = x110
y_test10 = y110
rf10 = RandomForestClassifier()
rf.fit(x_train10, y_train10)
rf_pred = rf.predict(x_test10)
pipeline = make_pipeline(StandardScaler(), rf10)

train_sizes, train_scores, test_scores = learning_curve(estimator = pipeline, X=x_train10, y=y_train10,
                                                       cv=10, train_sizes=np.linspace(0.1,1,10),
                                                     n_jobs=1)
train_mean = np.mean(train_scores, axis=1)
train_std = np.std(train_scores, axis=1)
test_mean = np.mean(test_scores, axis=1)
test_std = np.std(test_scores, axis=1)

plt.plot(train_sizes, train_mean, color='blue', marker='o', markersize=5, label='Training Score')
plt.fill_between(train_sizes, train_mean + train_std, train_mean - train_std, alpha=0.15, color='blue')
plt.plot(train_sizes, test_mean, color='green', marker='+', markersize=5, linestyle='--', label='Cross Validation Score')
plt.fill_between(train_sizes, test_mean + test_std, test_mean - test_std, alpha=0.15, color='green')
plt.title('OU STEM data without demography')
plt.xlabel('Training Data Size')
plt.ylabel('Model Score')
plt.grid()
plt.ylim(0.0, 1.10)
plt.legend(loc='lower right')
plt.show()

# %%
educationdata11 = pd.read_csv("filepath")
educationdata12 = pd.read_csv("filepath")
educationdata13 = pd.read_csv("filepath")
educationdata14 = pd.read_csv("filepath")
educationdata15 = pd.read_csv("filepath")

# %%
x113 = educationdata13.drop("final_result", axis = 1)
y113 = educationdata13.final_result
x_train13 = x113
y_train13 = y113
x_test13 = x113
y_test13 = y113
rf13 = RandomForestClassifier()
rf.fit(x_train13, y_train13)
rf_pred = rf.predict(x_test13)
pipeline = make_pipeline(StandardScaler(), rf13)

train_sizes, train_scores, test_scores = learning_curve(estimator = pipeline, X=x_train13, y=y_train13,
                                                       cv=10, train_sizes=np.linspace(0.1,1,10),
                                                     n_jobs=1)
train_mean = np.mean(train_scores, axis=1)
train_std = np.std(train_scores, axis=1)
test_mean = np.mean(test_scores, axis=1)
test_std = np.std(test_scores, axis=1)

plt.plot(train_sizes, train_mean, color='blue', marker='o', markersize=5, label='Training Score')
plt.fill_between(train_sizes, train_mean + train_std, train_mean - train_std, alpha=0.15, color='blue')
plt.plot(train_sizes, test_mean, color='green', marker='+', markersize=5, linestyle='--', label='Cross Validation Score')
plt.fill_between(train_sizes, test_mean + test_std, test_mean - test_std, alpha=0.15, color='green')
plt.title('Columbian Engineering data only demography')
plt.xlabel('Training Data Size')
plt.ylabel('Model Score')
plt.grid()
plt.ylim(0.0, 1.10)
plt.legend(loc='lower right')
plt.show()

# %%
x114 = educationdata14.drop("final_result", axis = 1)
y114 = educationdata14.final_result
x_train14 = x114
y_train14 = y114
x_test14 = x114
y_test14 = y114
rf14 = RandomForestClassifier()
rf.fit(x_train14, y_train14)
rf_pred = rf.predict(x_test14)
pipeline = make_pipeline(StandardScaler(), rf14)

train_sizes, train_scores, test_scores = learning_curve(estimator = pipeline, X=x_train14, y=y_train14,
                                                       cv=10, train_sizes=np.linspace(0.1,1,10),
                                                     n_jobs=1)
train_mean = np.mean(train_scores, axis=1)
train_std = np.std(train_scores, axis=1)
test_mean = np.mean(test_scores, axis=1)
test_std = np.std(test_scores, axis=1)

plt.plot(train_sizes, train_mean, color='blue', marker='o', markersize=5, label='Training Score')
plt.fill_between(train_sizes, train_mean + train_std, train_mean - train_std, alpha=0.15, color='blue')
plt.plot(train_sizes, test_mean, color='green', marker='+', markersize=5, linestyle='--', label='Cross Validation Score')
plt.fill_between(train_sizes, test_mean + test_std, test_mean - test_std, alpha=0.15, color='green')
plt.title('SPU data only demography')
plt.xlabel('Training Data Size')
plt.ylabel('Model Score')
plt.grid()
plt.ylim(0.0, 1.10)
plt.legend(loc='lower right')
plt.show()

# %%
x115 = educationdata15.drop("final_result", axis = 1)
y115 = educationdata15.final_result
x_train15 = x115
y_train15 = y115
x_test15 = x115
y_test15 = y115
rf15 = RandomForestClassifier()
rf.fit(x_train15, y_train15)
rf_pred = rf.predict(x_test15)
pipeline = make_pipeline(StandardScaler(), rf15)

train_sizes, train_scores, test_scores = learning_curve(estimator = pipeline, X=x_train15, y=y_train15,
                                                       cv=10, train_sizes=np.linspace(0.1,1,10),
                                                     n_jobs=1)
train_mean = np.mean(train_scores, axis=1)
train_std = np.std(train_scores, axis=1)
test_mean = np.mean(test_scores, axis=1)
test_std = np.std(test_scores, axis=1)

plt.plot(train_sizes, train_mean, color='blue', marker='o', markersize=5, label='Training Score')
plt.fill_between(train_sizes, train_mean + train_std, train_mean - train_std, alpha=0.15, color='blue')
plt.plot(train_sizes, test_mean, color='green', marker='+', markersize=5, linestyle='--', label='Cross Validation Score')
plt.fill_between(train_sizes, test_mean + test_std, test_mean - test_std, alpha=0.15, color='green')
plt.title('OU STEM data only demography')
plt.xlabel('Training Data Size')
plt.ylabel('Model Score')
plt.grid()
plt.ylim(0.0, 1.10)
plt.legend(loc='lower right')
plt.show()
