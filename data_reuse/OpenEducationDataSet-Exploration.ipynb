# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
educationdata1 = pd.read_csv("filepath here")
educationdata2 = pd.read_csv("filepath here")

# %%
educationdata1.head()
# Out:
#    id_student  final_result  gender  region  highest_education  imd_band  \
# 0       24391             4       1       6                  3         5
# 1       26023             3       1       8                  2         4
# 2       32239             3       2       2                  3         2
# 3       35001             2       2       6                  2        10
# 4       60405             4       2       5                  3         4
#
#    age_band  num_of_prev_attempts  studied_credits  disabilit1  ...  \
# 0         2                     0               30           0  ...
# 1         3                     0               30           0  ...
# 2         2                     0               30           0  ...
# 3         3                     0               30           0  ...
# 4         3                     0               30           0  ...
#
#    Assessn_1forumng  Assessn_1homepage  Assessn_1oucontent  Assessn_1resource  \
# ...

# %%
educationdata2.head()
# Out:
#    id_student  final_result  gender  region  highest_education  imd_band  \
# 0       25150             3       1       8                  1         1
# 1       27780             3       1      11                  3         4
# 2       29639             3       1      13                  2         0
# 3       29820             3       1       4                  1         7
# 4       35340             3       1       1                  3         8
#
#    age_band  num_of_prev_attempts  studied_credits  disabilit1  ...  \
# 0         2                     0               60           0  ...
# 1         2                     0              150           0  ...
# 2         2                     0               30           0  ...
# 3         2                     0               60           0  ...
# 4         2                     0               60           0  ...
#
#    Assessn_1forumng  Assessn_1homepage  Assessn_1oucontent  Assessn_1resource  \
# ...

# %%
educationdata1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 952 entries, 0 to 951
# Data columns (total 36 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id_student            952 non-null    int64
#  1   final_result          952 non-null    int64
#  2   gender                952 non-null    int64
#  3   region                952 non-null    int64
#  4   highest_education     952 non-null    int64
#  5   imd_band              952 non-null    int64
#  6   age_band              952 non-null    int64
#  7   num_of_prev_attempts  952 non-null    int64
#  8   studied_credits       952 non-null    int64
#  9   disabilit1            952 non-null    int64
#  10  date_registration     952 non-null    int64
#  11  date_unregistration   952 non-null    int64
#  12  Assessment 1          952 non-null    int64
#  13  Assessmentn-1         952 non-null    float64
#  14  Last assessment       952 non-null    int64
# ...

# %%
educationdata2.isnull().sum()
# Out:
# id_student              0
# final_result            0
# gender                  0
# region                  0
# highest_education       0
# imd_band                0
# age_band                0
# num_of_prev_attempts    0
# studied_credits         0
# disabilit1              0
# date_registration       0
# date_unregistration     0
# Assessment 1            0
# Assessmentn-1           0
# Last assessment         0
# Exam                    0
# Premoduleforumng        0
# Premodulehomepage       0
# Premoduleoucontent      0
# Premoduleresource       0
# Premodulesubpage        0
# Assess1forumng          0
# Assess1homepage         0
# Assess1oucontent        0
# Assess1resource         0
# Assess1subpage          0
# Assessn_1forumng        0
# Assessn_1homepage       0
# Assessn_1oucontent      0
# Assessn_1resource       0
# Assessn_1subpage        0
# Preexamforumng          0
# Preexamhomepage         0
# Preexamoucontent        0
# Preexamresource         0
# ...

# %%
summary = educationdata1.describe()
summary = summary.transpose()
summary
# Out:
#                       count           mean            std      min  \
# id_student            952.0  690353.813025  489306.958787  24391.0
# final_result          952.0       2.700630       0.803305      1.0
# gender                952.0       1.813025       0.390096      1.0
# region                952.0       5.022059       3.078117      1.0
# highest_education     952.0       2.390756       0.657112      1.0
# imd_band              952.0       5.559874       2.750124      0.0
# age_band              952.0       2.380252       0.487864      1.0
# num_of_prev_attempts  952.0       0.000000       0.000000      0.0
# studied_credits       952.0      34.422269      15.623469     30.0
# disabilit1            952.0       0.123950       0.329697      0.0
# date_registration     952.0     -59.574580      38.718791   -190.0
# date_unregistration   952.0       4.625000      29.436615   -143.0
# Assessment 1          952.0      69.537815      40.829937      0.0
# ...

# %%
summary = educationdata2.describe()
summary = summary.transpose()
summary
# Out:
#                       count           mean            std      min        25%  \
# id_student            694.0  684946.092219  478371.937936  25150.0  544821.25
# final_result          694.0       2.368876       0.969646      1.0       2.00
# gender                694.0       1.109510       0.312503      1.0       1.00
# region                694.0       6.427954       3.550074      1.0       3.00
# highest_education     694.0       2.298271       0.808735      1.0       2.00
# imd_band              694.0       5.551873       2.973581      0.0       3.00
# age_band              694.0       2.243516       0.439477      1.0       2.00
# num_of_prev_attempts  694.0       0.093660       0.291565      0.0       0.00
# studied_credits       694.0      60.850144      29.475903     30.0      30.00
# disabilit1            694.0       0.060519       0.238617      0.0       0.00
# date_registration     694.0     -65.089337      49.858595   -275.0     -93.00
# ...

# %%
count = educationdata1.final_result.value_counts()
count
# Out:
# 3    451
# 2    294
# 4    141
# 1     66
# Name: final_result, dtype: int64

# %%
count.plot.bar()
plt.title('Student outcomes'),plt.xlabel('Outcome'),plt.ylabel('Number')
# Out:
# (Text(0.5, 1.0, 'Student outcomes'),
#  Text(0.5, 0, 'Outcome'),
#  Text(0, 0.5, 'Number'))

# %%
count = educationdata2.final_result.value_counts()
count
# Out:
# 3    285
# 1    173
# 2    164
# 4     72
# Name: final_result, dtype: int64

# %%
count.plot.bar()
plt.title('Student outcomes'),plt.xlabel('Outcome'),plt.ylabel('Number')
# Out:
# (Text(0.5, 1.0, 'Student outcomes'),
#  Text(0.5, 0, 'Outcome'),
#  Text(0, 0.5, 'Number'))

# %%
educationdata1.drop(educationdata1.columns[[-1, 0]], axis=1, inplace=True)
educationdata1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 952 entries, 0 to 951
# Data columns (total 34 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   final_result          952 non-null    int64
#  1   gender                952 non-null    int64
#  2   region                952 non-null    int64
#  3   highest_education     952 non-null    int64
#  4   imd_band              952 non-null    int64
#  5   age_band              952 non-null    int64
#  6   num_of_prev_attempts  952 non-null    int64
#  7   studied_credits       952 non-null    int64
#  8   disabilit1            952 non-null    int64
#  9   date_registration     952 non-null    int64
#  10  date_unregistration   952 non-null    int64
#  11  Assessment 1          952 non-null    int64
#  12  Assessmentn-1         952 non-null    float64
#  13  Last assessment       952 non-null    int64
#  14  Exam                  952 non-null    int64
# ...

# %%
educationdata2.drop(educationdata2.columns[[-1, 0]], axis=1, inplace=True)
educationdata2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 694 entries, 0 to 693
# Data columns (total 34 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   final_result          694 non-null    int64
#  1   gender                694 non-null    int64
#  2   region                694 non-null    int64
#  3   highest_education     694 non-null    int64
#  4   imd_band              694 non-null    int64
#  5   age_band              694 non-null    int64
#  6   num_of_prev_attempts  694 non-null    int64
#  7   studied_credits       694 non-null    int64
#  8   disabilit1            694 non-null    int64
#  9   date_registration     694 non-null    int64
#  10  date_unregistration   694 non-null    int64
#  11  Assessment 1          694 non-null    float64
#  12  Assessmentn-1         694 non-null    float64
#  13  Last assessment       694 non-null    int64
#  14  Exam                  694 non-null    int64
# ...

# %%
educationdata1_corr = educationdata1.corr()
educationdata1_corr
# Out:
#                       final_result    gender    region  highest_education  \
# final_result              1.000000  0.029234  0.007777           0.038577
# gender                    0.029234  1.000000 -0.036844           0.055603
# region                    0.007777 -0.036844  1.000000          -0.027660
# highest_education         0.038577  0.055603 -0.027660           1.000000
# imd_band                 -0.041618  0.008486  0.001272          -0.005978
# age_band                  0.011730  0.009309 -0.009093          -0.034289
# num_of_prev_attempts           NaN       NaN       NaN                NaN
# studied_credits          -0.069512 -0.026369  0.027925          -0.036369
# disabilit1               -0.002677  0.008691  0.021134          -0.010237
# date_registration        -0.113687 -0.085789  0.036016           0.038384
# date_unregistration      -0.332973  0.040864  0.003805          -0.054497
# Assessment 1              0.637934  0.079073 -0.015230           0.034173
# ...

# %%
educationdata2_corr = educationdata2.corr()
educationdata2_corr
# Out:
#                       final_result    gender    region  highest_education  \
# final_result              1.000000 -0.019213  0.008989           0.001183
# gender                   -0.019213  1.000000  0.047443          -0.038075
# region                    0.008989  0.047443  1.000000          -0.053068
# highest_education         0.001183 -0.038075 -0.053068           1.000000
# imd_band                 -0.115247  0.006301  0.013956           0.034660
# age_band                  0.022552 -0.047357 -0.005849          -0.090975
# num_of_prev_attempts     -0.004986 -0.033546  0.029531           0.040465
# studied_credits          -0.137208  0.127735 -0.029338           0.010231
# disabilit1               -0.003073  0.065806 -0.039135           0.048399
# date_registration         0.102434 -0.044381  0.027682          -0.033049
# date_unregistration      -0.338039  0.084965 -0.011480           0.027691
# Assessment 1              0.671021 -0.005858 -0.032687           0.039010
# ...

# %%
f,ax = plt. subplots(figsize = (10,10))
#sns.heatmap(cancerdata_corr,  annot = True, cmap =plt.cm.Reds)
sns.heatmap(educationdata1_corr)
# Out:
# <AxesSubplot:>

# %%
f,ax = plt. subplots(figsize = (10,10))
#sns.heatmap(cancerdata_corr,  annot = True, cmap =plt.cm.Reds)
sns.heatmap(educationdata2_corr)
# Out:
# <AxesSubplot:>

# %%
featureMeans = list(educationdata1.columns[1:10])

# %%
featureMeans = list(educationdata2.columns[1:10])

# %%
educationdata1
# Out:
#      final_result  gender  region  highest_education  imd_band  age_band  \
# 0               4       1       6                  3         5         2
# 1               3       1       8                  2         4         3
# 2               3       2       2                  3         2         2
# 3               2       2       6                  2        10         3
# 4               4       2       5                  3         4         3
# ..            ...     ...     ...                ...       ...       ...
# 947             3       1       5                  3         7         2
# 948             1       2       6                  2         9         3
# 949             2       2       8                  3         6         2
# 950             4       2       1                  3         4         3
# 951             2       2       3                  3         2         3
#
#      num_of_prev_attempts  studied_credits  disabilit1  date_registration  \
# ...

# %%
educationdata2
# Out:
#      final_result  gender  region  highest_education  imd_band  age_band  \
# 0               3       1       8                  1         1         2
# 1               3       1      11                  3         4         2
# 2               3       1      13                  2         0         2
# 3               3       1       4                  1         7         2
# 4               3       1       1                  3         8         2
# ..            ...     ...     ...                ...       ...       ...
# 689             3       1       8                  3         6         3
# 690             3       1      11                  3        10         2
# 691             4       1       6                  2         6         2
# 692             3       1      11                  3         9         2
# 693             2       1       9                  2        10         2
#
#      num_of_prev_attempts  studied_credits  disabilit1  date_registration  \
# ...

# %%
x1 = educationdata1.drop("final_result", axis = 1)
y1 = educationdata1.final_result

# %%
x2 = educationdata2.drop("final_result", axis = 1)
y2 = educationdata2.final_result

# %%
educationdata1
# Out:
#      final_result  gender  region  highest_education  imd_band  age_band  \
# 0               4       1       6                  3         5         2
# 1               3       1       8                  2         4         3
# 2               3       2       2                  3         2         2
# 3               2       2       6                  2        10         3
# 4               4       2       5                  3         4         3
# ..            ...     ...     ...                ...       ...       ...
# 947             3       1       5                  3         7         2
# 948             1       2       6                  2         9         3
# 949             2       2       8                  3         6         2
# 950             4       2       1                  3         4         3
# 951             2       2       3                  3         2         3
#
#      num_of_prev_attempts  studied_credits  disabilit1  date_registration  \
# ...

# %%
educationdata2
# Out:
#      final_result  gender  region  highest_education  imd_band  age_band  \
# 0               3       1       8                  1         1         2
# 1               3       1      11                  3         4         2
# 2               3       1      13                  2         0         2
# 3               3       1       4                  1         7         2
# 4               3       1       1                  3         8         2
# ..            ...     ...     ...                ...       ...       ...
# 689             3       1       8                  3         6         3
# 690             3       1      11                  3        10         2
# 691             4       1       6                  2         6         2
# 692             3       1      11                  3         9         2
# 693             2       1       9                  2        10         2
#
#      num_of_prev_attempts  studied_credits  disabilit1  date_registration  \
# ...

# %%
from sklearn.model_selection import train_test_split
#x_train, x_test, y_train, y_test = train_test_split(x,y, train_size = 0.75)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif = pd.DataFrame()
vif.head
# Out:
# <bound method NDFrame.head of Empty DataFrame
# Columns: []
# Index: []>

# %%
x1
# Out:
#      gender  region  highest_education  imd_band  age_band  \
# 0         1       6                  3         5         2
# 1         1       8                  2         4         3
# 2         2       2                  3         2         2
# 3         2       6                  2        10         3
# 4         2       5                  3         4         3
# ..      ...     ...                ...       ...       ...
# 947       1       5                  3         7         2
# 948       2       6                  2         9         3
# 949       2       8                  3         6         2
# 950       2       1                  3         4         3
# 951       2       3                  3         2         3
#
#      num_of_prev_attempts  studied_credits  disabilit1  date_registration  \
# 0                       0               30           0                -64
# 1                       0               30           0                -37
# ...

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
sc.fit_transform(x1)
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %%
x_train = x1
y_train = y1
x_test = x2
y_test = y2

# %%
x_train.shape
# Out:
# (952, 33)

# %%
y_train.shape
# Out:
# (952,)

# %%
x_test.shape
# Out:
# (694, 33)

# %%
y_test.shape
# Out:
# (694,)

# %%
from sklearn.tree import DecisionTreeClassifier
dtree = DecisionTreeClassifier()
dtree.fit(x_train, y_train)
dtree_pred = dtree.predict(x_test)
print("confusion_matrix :")
print(confusion_matrix(y_test, dtree_pred))
print("classification_report :")
print(classification_report(y_test, dtree_pred))
print("acc_score :")
print(accuracy_score(y_test, dtree_pred))
# Out:
# confusion_matrix :
# [[149  21   3   0]
#  [  5 136  14   9]
#  [  1  49 164  71]
#  [  0   9  32  31]]
# classification_report :
#               precision    recall  f1-score   support
#
#            1       0.96      0.86      0.91       173
#            2       0.63      0.83      0.72       164
#            3       0.77      0.58      0.66       285
#            4       0.28      0.43      0.34        72
#
#     accuracy                           0.69       694
#    macro avg       0.66      0.67      0.66       694
# weighted avg       0.73      0.69      0.70       694
#
# acc_score :
# 0.69164265129683

# %%
from sklearn.tree import DecisionTreeClassifier
dtree = DecisionTreeClassifier()
dtree.fit(x_train, y_train)
dtree_pred1 = dtree.predict(x_test)
print("confusion_matrix :")
print(confusion_matrix(y_test, dtree_pred1))
print("classification_report :")
print(classification_report(y_test, dtree_pred1))
print("acc_score :")
print(accuracy_score(y_test, dtree_pred1))
# Out:
# confusion_matrix :
# [[149  21   3   0]
#  [  5 135  16   8]
#  [  1  54 172  58]
#  [  0   6  42  24]]
# classification_report :
#               precision    recall  f1-score   support
#
#            1       0.96      0.86      0.91       173
#            2       0.62      0.82      0.71       164
#            3       0.74      0.60      0.66       285
#            4       0.27      0.33      0.30        72
#
#     accuracy                           0.69       694
#    macro avg       0.65      0.66      0.64       694
# weighted avg       0.72      0.69      0.70       694
#
# acc_score :
# 0.69164265129683

# %%
from sklearn.tree import DecisionTreeClassifier
dtree = DecisionTreeClassifier()
dtree.fit(x_train, y_train)
dtree_pred2 = dtree.predict(x_test)

# %%
dtree = DecisionTreeClassifier()
dtree.fit(x_train, y_train)
dtree_pred3 = dtree.predict(x_test)

# %%
dtree = DecisionTreeClassifier()
dtree.fit(x_train, y_train)
dtree_pred4 = dtree.predict(x_test)

# %%
dtree = DecisionTreeClassifier()
dtree.fit(x_train, y_train)
dtree_pred5 = dtree.predict(x_test)

# %%
dtree = DecisionTreeClassifier()
dtree.fit(x_train, y_train)
dtree_pred6 = dtree.predict(x_test)

# %%
dtree = DecisionTreeClassifier()
dtree.fit(x_train, y_train)
dtree_pred7 = dtree.predict(x_test)

# %%
dtree = DecisionTreeClassifier()
dtree.fit(x_train, y_train)
dtree_pred8 = dtree.predict(x_test)

# %%
dtree = DecisionTreeClassifier()
dtree.fit(x_train, y_train)
dtree_pred9 = dtree.predict(x_test)

# %%
dtree = DecisionTreeClassifier()
dtree.fit(x_train, y_train)
dtree_pred10 = dtree.predict(x_test)

# %%
print(classification_report(y_test, dtree_pred))
print(classification_report(y_test, dtree_pred1))
print(classification_report(y_test, dtree_pred2))
print(classification_report(y_test, dtree_pred3))
print(classification_report(y_test, dtree_pred4))
print(classification_report(y_test, dtree_pred5))
print(classification_report(y_test, dtree_pred6))
print(classification_report(y_test, dtree_pred7))
print(classification_report(y_test, dtree_pred8))
print(classification_report(y_test, dtree_pred9))
print(classification_report(y_test, dtree_pred10))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.93      0.86      0.89       173
#            2       0.66      0.83      0.74       164
#            3       0.74      0.56      0.64       285
#            4       0.27      0.42      0.33        72
#
#     accuracy                           0.69       694
#    macro avg       0.65      0.67      0.65       694
# weighted avg       0.72      0.69      0.69       694
#
#               precision    recall  f1-score   support
#
#            1       0.96      0.86      0.91       173
#            2       0.66      0.82      0.73       164
#            3       0.75      0.59      0.66       285
#            4       0.31      0.47      0.37        72
#
#     accuracy                           0.70       694
#    macro avg       0.67      0.69      0.67       694
# weighted avg       0.74      0.70      0.71       694
#
#               precision    recall  f1-score   support
#
# ...

# %%
print(accuracy_score(y_test, dtree_pred))
print(accuracy_score(y_test, dtree_pred1))
print(accuracy_score(y_test, dtree_pred2))
print(accuracy_score(y_test, dtree_pred3))
print(accuracy_score(y_test, dtree_pred4))
print(accuracy_score(y_test, dtree_pred5))
print(accuracy_score(y_test, dtree_pred6))
print(accuracy_score(y_test, dtree_pred7))
print(accuracy_score(y_test, dtree_pred8))
print(accuracy_score(y_test, dtree_pred9))
print(accuracy_score(y_test, dtree_pred10))
# Out:
# 0.6858789625360231
# 0.7002881844380403
# 0.69164265129683
# 0.6671469740634006
# 0.6801152737752162
# 0.6786743515850144
# 0.6729106628242075
# 0.6714697406340058
# 0.6902017291066282
# 0.6743515850144092
# 0.6974063400576369
